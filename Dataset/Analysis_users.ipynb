# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("users.csv")

# %%
df.head()
# Out:
#    _id                                                bio  \
# 0    0                 I am very honest and caring person
# 1    1                                Let's go on a date.
# 2    2                                        Loving life
# 3    3  Jai Maharashtra\r\n🥲Bharat Mata ki Jay.....\r\...
# 4    4                                                  🙄
#
#                            college country                 createdAt  \
# 0  ["Jawaharlal Nehru University"]      IN  2023-02-07T05:23:18.004Z
# 1                    ["Heritage "]      IN  2023-02-07T05:44:15.450Z
# 2  ["Jawaharlal Nehru University"]      IN  2023-02-07T05:57:29.233Z
# 3  ["Jawaharlal Nehru University"]      IN  2023-02-07T06:04:39.836Z
# 4  ["Jawaharlal Nehru University"]      IN  2023-02-07T07:05:14.605Z
#
#                         dob                 email  \
# 0  2002-07-16T00:00:00.000Z  9000000000@get.idyll
# 1  1999-02-26T00:00:00.000Z  9100000000@get.idyll
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1405 entries, 0 to 1404
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id                           1405 non-null   int64
#  1   bio                           1076 non-null   object
#  2   college                       1403 non-null   object
#  3   country                       1405 non-null   object
#  4   createdAt                     1405 non-null   object
#  5   dob                           1192 non-null   object
#  6   email                         1405 non-null   object
#  7   face_detection_probabilities  765 non-null    object
#  8   gender                        1258 non-null   object
#  9   height                        646 non-null    float64
#  10  insta_username                0 non-null      float64
#  11  interests                     1403 non-null   object
# ...

# %%
from datetime import datetime

# Convert datetime string to datetime object
df['createdAt'] = pd.to_datetime(df['createdAt'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Get current datetime
current_datetime = datetime.now()

# Calculate timedelta and convert to hours
df['createdAt'] = (current_datetime - df['createdAt']) / pd.Timedelta('1 hour')

# %%
df['dob'] = df['dob'].astype('object')

# %%
from datetime import datetime

# Convert 'dob' column to datetime
df['dob'] = pd.to_datetime(df['dob'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Calculate age from 'dob' column in years
current_year = pd.Timestamp.now().year
df['age'] = current_year - df['dob'].dt.year

# %%
from datetime import datetime

# Convert datetime string to datetime object
df['updatedAt'] = pd.to_datetime(df['updatedAt'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Get current datetime
current_datetime = datetime.now()

# Calculate timedelta and convert to hours
df['updatedAt'] = (current_datetime - df['updatedAt']) / pd.Timedelta('1 day')

# %%
from datetime import datetime

# Convert datetime string to datetime object
df['verified_at'] = pd.to_datetime(df['verified_at'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# Get current datetime
current_datetime = datetime.now()

# Calculate timedelta and convert to hours
df['verified_at'] = (current_datetime - df['verified_at']) / pd.Timedelta('1 day')

# %%
df.head()
# Out:
#    _id                                                bio  \
# 0    0                 I am very honest and caring person
# 1    1                                Let's go on a date.
# 2    2                                        Loving life
# 3    3  Jai Maharashtra\r\n🥲Bharat Mata ki Jay.....\r\...
# 4    4                                                  🙄
#
#                            college country   createdAt        dob  \
# 0  ["Jawaharlal Nehru University"]      IN  617.065488 2002-07-16
# 1                    ["Heritage "]      IN  616.716198 1999-02-26
# 2  ["Jawaharlal Nehru University"]      IN  616.495703 2001-01-08
# 3  ["Jawaharlal Nehru University"]      IN  616.376091 2000-08-20
# 4  ["Jawaharlal Nehru University"]      IN  615.366433 2000-07-31
#
#                   email                       face_detection_probabilities  \
# 0  9000000000@get.idyll                                 [90.7028079032898]
# ...

# %%
df.to_csv('users_analysis.csv', index=False)
